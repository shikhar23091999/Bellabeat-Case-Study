# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhar23091999/Bellabeat-Case-Study/blob/main/Bellabeat_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import missingno as msno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read(name):
    return pd.read_csv(f'/content/drive/MyDrive/Google Capstone /Fitabase Data 4.12.16-5.12.16/{name}.csv')

# %%
activity_data = read('dailyActivity_merged')
sleepday_data = read('sleepDay_merged')
weight_data = read('weightLogInfo_merged')

# %%
sleepday_data
# Out:
#              Id               SleepDay  ...  TotalMinutesAsleep  TotalTimeInBed
# 0    1503960366  4/12/2016 12:00:00 AM  ...                 327             346
# 1    1503960366  4/13/2016 12:00:00 AM  ...                 384             407
# 2    1503960366  4/15/2016 12:00:00 AM  ...                 412             442
# 3    1503960366  4/16/2016 12:00:00 AM  ...                 340             367
# 4    1503960366  4/17/2016 12:00:00 AM  ...                 700             712
# ..          ...                    ...  ...                 ...             ...
# 408  8792009665  4/30/2016 12:00:00 AM  ...                 343             360
# 409  8792009665   5/1/2016 12:00:00 AM  ...                 503             527
# 410  8792009665   5/2/2016 12:00:00 AM  ...                 415             423
# 411  8792009665   5/3/2016 12:00:00 AM  ...                 516             545
# 412  8792009665   5/4/2016 12:00:00 AM  ...                 439             463
#
# ...

# %%
sleepday_data['TotalTimeAwake'] = sleepday_data.TotalTimeInBed - sleepday_data.TotalMinutesAsleep
sleepday_data['ActivityDate'] = sleepday_data['SleepDay'].apply(lambda x: x[:9].strip())
sleepday_data.drop_duplicates(inplace=True)
sleepday_data.reset_index(drop=True, inplace=True)
sleepday_data.shape
# Out:
# (410, 7)

# %%
weight_data
# Out:
#             Id                   Date  ...  IsManualReport          LogId
# 0   1503960366   5/2/2016 11:59:59 PM  ...            True  1462233599000
# 1   1503960366   5/3/2016 11:59:59 PM  ...            True  1462319999000
# 2   1927972279   4/13/2016 1:08:52 AM  ...           False  1460509732000
# 3   2873212765  4/21/2016 11:59:59 PM  ...            True  1461283199000
# 4   2873212765  5/12/2016 11:59:59 PM  ...            True  1463097599000
# ..         ...                    ...  ...             ...            ...
# 62  8877689391    5/6/2016 6:43:35 AM  ...           False  1462517015000
# 63  8877689391    5/8/2016 7:35:53 AM  ...           False  1462692953000
# 64  8877689391    5/9/2016 6:39:44 AM  ...           False  1462775984000
# 65  8877689391   5/11/2016 6:51:47 AM  ...           False  1462949507000
# 66  8877689391   5/12/2016 6:42:53 AM  ...           False  1463035373000
#
# [67 rows x 8 columns]

# %%
weight_data['ActivityDate'] = weight_data['Date'].apply(lambda x: x[:9].strip())

# %%
sleepday_data.drop(['SleepDay'], axis=1, inplace=True)
weight_data.drop(['Date', 'LogId'], axis=1, inplace=True)

# %%
daily_data = pd.merge(activity_data, sleepday_data,how='left')
daily_data = pd.merge(activity_data, weight_data,how='left')

# %%
daily_data.head()
# Out:
#            Id ActivityDate  TotalSteps  ...  Fat  BMI  IsManualReport
# 0  1503960366    4/12/2016       13162  ...  NaN  NaN             NaN
# 1  1503960366    4/13/2016       10735  ...  NaN  NaN             NaN
# 2  1503960366    4/14/2016       10460  ...  NaN  NaN             NaN
# 3  1503960366    4/15/2016        9762  ...  NaN  NaN             NaN
# 4  1503960366    4/16/2016       12669  ...  NaN  NaN             NaN
#
# [5 rows x 20 columns]

# %%
daily_data['ActivityDate'] = daily_data['ActivityDate'].apply(lambda x: pd.to_datetime(x, format='%m/%d/%Y'))
daily_data
# Out:
#              Id ActivityDate  TotalSteps  ...  Fat        BMI  IsManualReport
# 0    1503960366   2016-04-12       13162  ...  NaN        NaN             NaN
# 1    1503960366   2016-04-13       10735  ...  NaN        NaN             NaN
# 2    1503960366   2016-04-14       10460  ...  NaN        NaN             NaN
# 3    1503960366   2016-04-15        9762  ...  NaN        NaN             NaN
# 4    1503960366   2016-04-16       12669  ...  NaN        NaN             NaN
# ..          ...          ...         ...  ...  ...        ...             ...
# 935  8877689391   2016-05-08       10686  ...  NaN  25.559999           False
# 936  8877689391   2016-05-09       20226  ...  NaN  25.610001           False
# 937  8877689391   2016-05-10       10733  ...  NaN        NaN             NaN
# 938  8877689391   2016-05-11       21420  ...  NaN  25.559999           False
# 939  8877689391   2016-05-12        8064  ...  NaN  25.139999           False
#
# [940 rows x 20 columns]

# %%
daily_data.isnull().sum().sort_values(ascending = False)
# Out:
# Fat                         938
# IsManualReport              873
# WeightPounds                873
# WeightKg                    873
# BMI                         873
# ModeratelyActiveDistance      0
# ActivityDate                  0
# TotalSteps                    0
# TotalDistance                 0
# TrackerDistance               0
# LoggedActivitiesDistance      0
# VeryActiveDistance            0
# SedentaryActiveDistance       0
# LightActiveDistance           0
# VeryActiveMinutes             0
# FairlyActiveMinutes           0
# LightlyActiveMinutes          0
# SedentaryMinutes              0
# Calories                      0
# Id                            0
# dtype: int64

# %%
daily_data=daily_data.drop_duplicates()

# %%
daily_data
# Out:
#              Id ActivityDate  TotalSteps  ...  Fat        BMI  IsManualReport
# 0    1503960366   2016-04-12       13162  ...  NaN        NaN             NaN
# 1    1503960366   2016-04-13       10735  ...  NaN        NaN             NaN
# 2    1503960366   2016-04-14       10460  ...  NaN        NaN             NaN
# 3    1503960366   2016-04-15        9762  ...  NaN        NaN             NaN
# 4    1503960366   2016-04-16       12669  ...  NaN        NaN             NaN
# ..          ...          ...         ...  ...  ...        ...             ...
# 935  8877689391   2016-05-08       10686  ...  NaN  25.559999           False
# 936  8877689391   2016-05-09       20226  ...  NaN  25.610001           False
# 937  8877689391   2016-05-10       10733  ...  NaN        NaN             NaN
# 938  8877689391   2016-05-11       21420  ...  NaN  25.559999           False
# 939  8877689391   2016-05-12        8064  ...  NaN  25.139999           False
#
# [940 rows x 20 columns]

# %%
daily_data.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'WeightKg',
#        'WeightPounds', 'Fat', 'BMI', 'IsManualReport'],
#       dtype='object')

# %%
columns = ['Id','TotalSteps','TotalDistance','TrackerDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance','LightActiveDistance','SedentaryActiveDistance','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories','WeightKg','WeightPounds']
n = 1
plt.figure(figsize=(20,15))

for x in columns:
  plt.subplot(4,4,n)
  n = n+1
  sns.boxplot(daily_data[x])
  plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# ...

# %%
msno.bar(daily_data)
